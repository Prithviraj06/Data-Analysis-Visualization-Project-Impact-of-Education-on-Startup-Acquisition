# %%
import pandas as pd
import datetime

# %%
df = pd.read_excel('FullDataset.xlsx', 'Acquisitions')

# %%
df.head()
# Out:
#                  company_permalink    company_name  \
# 0            /organization/waywire        #waywire
# 1      /organization/fluff-friends  (fluff)Friends
# 2                /organization/red           (RED)
# 3  /organization/vandaele-holdings               .
# 4        /organization/co-internet             .CO
#
#                         company_category_list company_market  \
# 0  |Entertainment|Politics|Social Media|News|           News
# 1                                         NaN            NaN
# 2                                |Nonprofits|     Nonprofits
# 3                                         NaN            NaN
# 4            |Registrars|Domains|Curated Web|     Registrars
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY  New York City     New York
# 1                  NaN                NaN            NaN          NaN
# 2                  USA                 NY  New York City     New York
# ...

# %%
pd.options.display.float_format = '{:.0f}'.format
df.head(5)
# Out:
#                  company_permalink    company_name  \
# 0            /organization/waywire        #waywire
# 1      /organization/fluff-friends  (fluff)Friends
# 2                /organization/red           (RED)
# 3  /organization/vandaele-holdings               .
# 4        /organization/co-internet             .CO
#
#                         company_category_list company_market  \
# 0  |Entertainment|Politics|Social Media|News|           News
# 1                                         NaN            NaN
# 2                                |Nonprofits|     Nonprofits
# 3                                         NaN            NaN
# 4            |Registrars|Domains|Curated Web|     Registrars
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY  New York City     New York
# 1                  NaN                NaN            NaN          NaN
# 2                  USA                 NY  New York City     New York
# ...

# %%
df = df[(df['acquired_year'] >= 2008) & (df['acquired_year'] <= 2014)]

# %%
df.head(5)
# Out:
#                  company_permalink    company_name  \
# 0            /organization/waywire        #waywire
# 1      /organization/fluff-friends  (fluff)Friends
# 2                /organization/red           (RED)
# 3  /organization/vandaele-holdings               .
# 4        /organization/co-internet             .CO
#
#                         company_category_list company_market  \
# 0  |Entertainment|Politics|Social Media|News|           News
# 1                                         NaN            NaN
# 2                                |Nonprofits|     Nonprofits
# 3                                         NaN            NaN
# 4            |Registrars|Domains|Curated Web|     Registrars
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY  New York City     New York
# 1                  NaN                NaN            NaN          NaN
# 2                  USA                 NY  New York City     New York
# ...

# %%
df.dropna(subset=['price_amount'])
# Out:
#                                       company_permalink  \
# 2                                     /organization/red
# 4                             /organization/co-internet
# 7                         /organization/0958572-b-c-ltd
# 21                            /organization/170-systems
# 22                              /organization/1form-com
# 24                     /organization/1st-united-bancorp
# 34                        /organization/24-7-real-media
# 37                              /organization/280-north
# 38                              /organization/280-north
# 43                 /organization/2nd-story-software-inc
# 45                                  /organization/2wire
# 52                         /organization/360naija-forum
# 55                                   /organization/3com
# 64                             /organization/3e-company
# 68                                   /organization/3par
# 69                                /organization/3pd-inc
# ...

# %%
df.tail(5)
# Out:
#                company_permalink company_name  company_category_list  \
# 13065  /organization/zync-render  Zync Render        |Digital Media|
# 13066  /organization/zynk-mobile  Zynk Mobile                    NaN
# 13067       /organization/zyrion   Zyrion Inc  |Networking|Software|
# 13068       /organization/zystor       Zystor        |Biotechnology|
# 13069  /organization/zytex-group  Zytex group        |Manufacturing|
#
#       company_market company_country_code company_state_code company_region  \
# 13065  Digital Media                  USA                 MA         Boston
# 13066            NaN                  NaN                NaN            NaN
# 13067       Software                  USA                 CA    SF Bay Area
# 13068  Biotechnology                  USA                 WI      Milwaukee
# 13069  Manufacturing                  IND                NaN         Mumbai
#
#       company_city                     acquirer_permalink  \
# ...

# %%
df = df[pd.notnull(df['price_amount'])]

# %%
df['price_amount'].isnull()
# Out:
# 2        False
# 4        False
# 7        False
# 21       False
# 22       False
# 24       False
# 34       False
# 37       False
# 38       False
# 43       False
# 45       False
# 52       False
# 55       False
# 64       False
# 68       False
# 69       False
# 71       False
# 75       False
# 76       False
# 79       False
# 84       False
# 86       False
# 89       False
# 107      False
# 116      False
# 121      False
# 122      False
# 123      False
# 131      False
# 136      False
#          ...
# 12958    False
# 12962    False
# 12964    False
# 12970    False
# 12978    False
# 12979    False
# 12982    False
# 12986    False
# 12991    False
# 12993    False
# 12995    False
# 12996    False
# 13002    False
# 13005    False
# 13021    False
# 13022    False
# 13027    False
# 13035    False
# 13036    False
# 13037    False
# 13039    False
# 13040    False
# 13044    False
# 13047    False
# 13052    False
# 13055    False
# 13058    False
# ...

# %%
df['company_name'].nunique()
# Out:
# 3229

# %%
df['company_market'].nunique()
# Out:
# 319

# %%
df['price_currency_code'].nunique()
# Out:
# 10

# %%
list(df.columns.values)
# Out:
# ['company_permalink',
#  'company_name',
#  'company_category_list',
#  'company_market',
#  'company_country_code',
#  'company_state_code',
#  'company_region',
#  'company_city',
#  'acquirer_permalink',
#  'acquirer_name',
#  'acquirer_category_list',
#  'acquirer_market',
#  'acquirer_country_code',
#  'acquirer_state_code',
#  'acquirer_region',
#  'acquirer_city',
#  'acquired_at',
#  'acquired_month',
#  'acquired_quarter',
#  'acquired_year',
#  'price_amount',
#  'price_currency_code']

# %%
df.to_csv("CleanData1.csv", index=False)
